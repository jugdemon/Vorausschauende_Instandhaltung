# %% [markdown]
# # Vorausschauende Instandhaltung

# %% [markdown]
# Dieses Notizbuch basiert auf dem github Quellcode-Verzeichnis von Jan Werth: https://github.com/JanderHungrige/PumpSensor
#
# Eine ausführliche Beschreibung ist zu lesen bei Medium: https://towardsdatascience.com/lstm-for-predictive-maintenance-on-pump-sensor-data-b43486eb3210
#
# Der Code wurde von Jascha Grübel für diese Übung adaptiert.

# %% [markdown]
# ## Vorbereitung von Python in Jupyter

# %% [markdown]
# Jupyter läuft in einer separaten Umgebung und greift üblicherweise nicht auf die System Installation von Python zu. Um Packete zu installieren, lohnt es sich diese innerhalb des Notizbuches zu laden. Mehr details können hier gelesen werden: https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %% [markdown]
# ### Packet-Installation

# %% [markdown]
# TensorFlow ist generell schwierig zu installieren, da es nur mit bestimmten Python-Versionen kompatibel ist. Es ist nötig höchstens Python 3.11 zu installieren, daher bietet sich folgende Installationsanweisung für Jupyter an: https://www.timescale.com/blog/jupyter-notebook-tutorial-setup-python-and-jupyter-notebooks-macos/

# %%
import sys
sys.version
sys.path
# Out:
# ['/Users/jgruebel',
#  '/Users/jgruebel/.pyenv/versions/3.11.2/lib/python311.zip',
#  '/Users/jgruebel/.pyenv/versions/3.11.2/lib/python3.11',
#  '/Users/jgruebel/.pyenv/versions/3.11.2/lib/python3.11/lib-dynload',
#  '',
#  '/Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages']

# %% [markdown]
# Packete werden mit "!" geladen um sicherzustellen, dass sie in der python environment des Juypter-Labs sind.

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install scikit-learn
# !{sys.executable} -m pip install tensorflow
# Out:
# Requirement already satisfied: pip in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (23.3.1)
# Requirement already satisfied: requests in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests) (2023.11.17)
# Requirement already satisfied: pandas in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (1.26.2)
# Requirement already satisfied: scikit-learn in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: tensorflow in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.26.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.2.2)

# %% [markdown]
# ### Packete importieren

# %% [markdown]
# Wir laden mehrere Packete komplett und aus einigen Packeten laden wir nur einzelne Funktionalitäten.

# %%
from os.path import exists
import requests
import zipfile

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import cm

import numpy as np
from numpy import savetxt 

import tensorflow as tf
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

from math import sqrt
    
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

# %% [markdown]
# ### Packete konfigurieren

# %% [markdown]
# Für die anschauliche Visualisierung im Notizbuch vergrössern wir die Figuren.

# %%
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# ## Randomisierung fixieren

# %% [markdown]
# Modelle trainieren ist sehr stark von der Initialisierung abhängig. Wir fixieren alle Zufallszahlen.

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 1337

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Datenbereitstellung

# %% [markdown]
# Die Daten können hier heruntergeladen werden: https://ga-data-cases.s3.eu-central-1.amazonaws.com/pump_sensor.zip
#
# Die Daten müssen neben dem Notizbuch im selben Ordner abgelegt werden, um von Jupyter geladen werden zu können.

# %% [markdown]
# ### Daten herunterladen

# %% [markdown]
# Um das Notizbuch in mybinder effektiv nutzen zu können, müssen die Daten zur Laufzeit heruntergeladen werden.

# %%
if not exists('pump_sensor.zip'):
    url = 'https://ga-data-cases.s3.eu-central-1.amazonaws.com/pump_sensor.zip'
    
    response = requests.get(url, stream=True)
    with open('pump_sensor.zip', "wb") as f:
        for chunk in response.iter_content(chunk_size=512):
            if chunk:  # filter out keep-alive new chunks
                f.write(chunk)

# %% [markdown]
# ### Daten einlesen

# %% [markdown]
# Die heruntergeladenen Daten werden entpackt und als pandas dataframe geladen.

# %%
if not exists('pump_sensor.csv'):
    with zipfile.ZipFile('pump_sensor.zip', 'r') as zip_ref:
        zip_ref.extractall()

# %%
def daten_lesen(path):
    daten=pd.read_csv(path)
    senornamen=daten.keys()[2:-1] #geht beides
    return daten, senornamen

daten,sensor_namen=daten_lesen('pump_sensor.csv')

# %% [markdown]
# ## Datenübersicht

# %% [markdown]
# Zuerst werden grobe Details der Daten überprüft. Dies ist wichtig, um später beurteilen zu können, ob Daten sich wie erwartet transformieren oder ob wir einen Fehler begangen haben.
#
# Wir explorieren die Sensordaten, sowie die Status-Zustände, die wir von der Pumpe erhalten können.

# %%
def daten_explorieren(daten):
    print('Datenübersicht: ')
    print(daten.shape); print()
    print('Schlüssel :') ; print(daten.keys()); print()
    print( 'Statusoptionen: ');  print( daten['machine_status'].unique()); print()
    print (daten['machine_status'].value_counts()); print()
    info=daten.describe()
    varianz=pd.DataFrame({'Var':daten.iloc[:,2:-1].var()})
    info=pd.concat([info,varianz.transpose()])
    return daten.head(), daten.tail(), info

Kopf,Schwanz, information=daten_explorieren(daten)
# Out:
# Datenübersicht:
# (220320, 55)
#
# Schlüssel :
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')
#
# Statusoptionen:
# ['NORMAL' 'BROKEN' 'RECOVERING']
#
# machine_status
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: count, dtype: int64

# %% [markdown]
# Ein kurzer Blick auf den Kopf der Daten gibt uns eine Übersicht, was wir zu erwarten haben.

# %%
Kopf
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# Um die Visualisierung der Rohdaten zu ermöglichen, benötigen wir einige Plot-Funktionen.

# %%
def plot_helfer(daten,plot_type,titel, abspeichern=False,axis = None,ohne_legende=False,scaleXLimit = True):
    if axis is None:
        fig=plt.figure()
        daten.plot(kind=plot_type)
        plt.title(titel)
        if scaleXLimit:
            plt.xlim(0, daten.shape[0])
    else:
        daten.plot(kind=plot_type,ax=axis)
        if ohne_legende: 
            axis.get_legend().remove()
        if scaleXLimit:
            axis.set_xlim(0, daten.shape[0])
    if abspeichern==True:
        plt.savefig(titel+'.png', format='png', dpi=300, transparent=True)  
  
def plot_Zielfunktion(daten, spalte='target', abspeichern=False, name='target'):
    y=daten[spalte]; x=np.linspace(1,len(y),len(y))
    plt.plot(x,y)
    plt.ylabel('Klasse')
    plt.title('Zielfunktion')
    labels = ['Normal','Kaputt','Wiederherstellung']
    if spalte=='target':
        plt.yticks([1,0,2], labels, rotation='vertical')
    elif spalte=='machine_status':
        plt.yticks([0,1,2], labels, rotation='vertical')
    if abspeichern==True:
        plt.savefig(name+'.png', format='png', dpi=300, transparent=True)
    plt.show()

# %% [markdown]
# ### Zielfunktion
# Wir schauen uns nun dei Zielfunktion an, die es zu vorhersagen gilt.  Es fällt auf, dass die "Kaputt"-Klasse fast nie vorkommt, sehr wohl aber die Wiederherstellung der Funktionalität nach dem "kaputtgehen".

# %%
plot_Zielfunktion(daten,spalte='machine_status',abspeichern=False,name='Klassen')

# %% [markdown]
# ### Datenqualität
# Wir versuchen nun aufgrund von "NaN"-Zuständen, Standardabweichungen und Varianz die Qualität der Daten einzuordnen. Dies ist wichtig, da Maschinelles Lernen am besten mit einem guten Signal funktioniert und durch Rauschen und Fehler in den Daten starke Leistungseinbussen hinnehmen muss.

# %%
plot_helfer((daten.isna().sum())[2:-1],'bar','Anzahl der NaN in Rohdaten',abspeichern=False) 
plot_helfer(information.loc[['std']][sensor_namen].transpose(),'bar','Standardabweichung der Rohdaten',abspeichern=False)
plot_helfer(information.loc[['Var']][sensor_namen].transpose(),'bar','Varianz der Rohdaten',abspeichern=False)

# %% [markdown]
# ### Daten-Reparatur (data wrangling)
#
# Um die Daten zu reparieren, müssen wir die Anzahl der NaN minimieren und die Varianz der Daten maximieren. Alle NaNs zu verwerfen würde zu zu grossem Datenverlust führen.
#
# Sensor 00, 06,07,08, 09 und 15 haben viele NaNs und keine Varianz und können daher sorglos entfernt werden.
#
# Sensor 50 und 51 haben Varianz und müssen daher genauer betrachtet werden:

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
plot_helfer(daten['sensor_50'],'line',str('sensor_50'),axis = axes[0])
plot_helfer(daten['sensor_51'],'line',str('sensor_51'),axis = axes[1])

# %% [markdown]
# Es gibt einen Datenverlust zwischen 110000 und 140000 in Sensor 51 sowie einen totalverlust in sensor 50 ab 145000.
#
# Wir vergrössen der Ausschnitt des Datenverlusts für eine nähere Beobachtung:

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
plot_helfer(daten['sensor_50'][110000:143279],'line',str('sensor_50'),axis = axes[0],scaleXLimit=False)
plot_helfer(daten['sensor_51'][110000:143279],'line',str('sensor_51'),axis = axes[1],scaleXLimit=False)

# %% [markdown]
# Sensor 50 und 51 scheinen ein sehr ähnliches Signal zu haben. Um die maximale Varianz für das Maschinelle Lernen aus den Daten zu extrahieren bietet es sich an den Sensor 51 mit Daten aus 50 zu reparieren und danach den Sensor 50 zu verwerfen. Vermerk: loc ist eckigen Klammern zu bevorzugen, da es effizienter ist und keine Kopien produziert.
#
# Zu guter letzt lohnt es sich durch "Auffüllen" kurze NaNs-Reihen in den Daten, die typischerweise durch Unterbrechung von Datenübertragung entstehen können, zu reparieren.

# %%
def daten_reparatur(daten, plotten=False):
    
    daten.iloc[114900:135000,[53]]=daten.iloc[114900:135000,[52]]
    daten=daten.drop(labels=['sensor_00','sensor_06','sensor_07','sensor_08','sensor_09','sensor_15','sensor_50'],axis=1)

    
    daten=daten.ffill(limit=30)
    daten=daten.dropna()
    if plotten==True:
        print((daten.isna().sum()))
        plot_helfer((daten.isna().sum()[2:-1]),'bar','Verbliebene NaNs',abspeichern=False)
        
    return daten

reparierte_daten = daten_reparatur(daten, plotten=True)
# Out:
# Unnamed: 0        0
# timestamp         0
# sensor_01         0
# sensor_02         0
# sensor_03         0
# sensor_04         0
# sensor_05         0
# sensor_10         0
# sensor_11         0
# sensor_12         0
# sensor_13         0
# sensor_14         0
# sensor_16         0
# sensor_17         0
# sensor_18         0
# sensor_19         0
# sensor_20         0
# sensor_21         0
# sensor_22         0
# sensor_23         0
# sensor_24         0
# sensor_25         0
# sensor_26         0
# sensor_27         0
# sensor_28         0
# sensor_29         0
# sensor_30         0
# sensor_31         0
# sensor_32         0
# sensor_33         0
# sensor_34         0
# sensor_35         0
# sensor_36         0
# sensor_37         0
# sensor_38         0
# sensor_39         0
# sensor_40         0
# sensor_41         0
# sensor_42         0
# sensor_43         0
# sensor_44         0
# sensor_45         0
# sensor_46         0
# sensor_47         0
# sensor_48         0
# sensor_49         0
# sensor_51         0
# machine_status    0
# dtype: int64

# %%
plot_helfer(reparierte_daten['sensor_51'][114000:150000],'line',str('sensor_51'),scaleXLimit=False)

# %% [markdown]
# Wir können sehen, dass nun keine NaNs mehr übrig sind und Sensor 51 über kein grosses Loch mehr erfügt. Die Auswahl der Methoden für das Reparieren von Daten ist eine Kunst und keine Wissenschaft. Es bedarf viel Erfahrung, um nicht künstliche Signale zu erzeugen.

# %%
fig, axes = plt.subplots(nrows=7, ncols=7)
visualisierungs_daten = reparierte_daten.drop(labels=['Unnamed: 0','timestamp','machine_status'],axis=1)
for j in range(7):
    for k in range(7):
        if (j*7+k<45):
            plot_helfer(visualisierungs_daten.iloc[:,j*7+k],'line',visualisierungs_daten.iloc[:,j*7+k].name,axis = axes[j,k])
for ax in axes[6,3:7]:
    ax.set_axis_off()

# %% [markdown]
# Hier sehen wir nun eine Übersicht der Rohdaten nach der Reparatur.

# %% [markdown]
# # Daten kodieren

# %% [markdown]
# Klassen müssen generell für Maschinelles Lernen zu Zahlen konvertiert werden.

# %%
def Vorverarbeitung_Y(data):
    #Label Mapping
    le = preprocessing.LabelEncoder()
    le.fit(data)
    encoded_y=le.transform(data)
    #Get the Label map
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print(le_name_mapping)
    return pd.DataFrame(encoded_y,columns=['target'])

kodiertes_Y=Vorverarbeitung_Y(reparierte_daten['machine_status']);

plot_Zielfunktion(kodiertes_Y,spalte='target', abspeichern=True , name='Klassen')
# Out:
# {'BROKEN': 0, 'NORMAL': 1, 'RECOVERING': 2}

# %%
fig, axes = plt.subplots(nrows=7, ncols=7)
skalier = MinMaxScaler()
skalierte_daten = pd.DataFrame(skalier.fit_transform(visualisierungs_daten), columns=visualisierungs_daten.columns)
for j in range(7):
    for k in range(7):
        if (j*7+k<45):
            plot_helfer(skalierte_daten.iloc[:,j*7+k],'line',skalierte_daten.iloc[:,j*7+k].name,axis = axes[j,k])
            plot_helfer(kodiertes_Y,'line',skalierte_daten.iloc[:,j*7+k].name,axis = axes[j,k],ohne_legende = True)

for ax in axes[6,3:7]:
    ax.set_axis_off()

# %% [markdown]
# # Vorhersage für Vorausschauende Instandhaltung

# %% [markdown]
# Objekt-Orientiertes Programmieren (OOP) hat den Vorteil, dass repetitive Schritte auf ähnlichen Objekten generalisiert werden können und vereinfacht dargestellt werden könnnen.
#
# Im ersten Teil dieser Übung wurden einfache Funktionen geschrieben, um Aufgaben zusammenzufassen. OOP verschiebt den Fokus von was die Aufgabe ist zu "für was" die Aufgabe ist. Im folgenden werden wir Objekte für Zeitreihen und Datensätze verwenden, um Funktionen an diese Objekte zu binden und komplizierte Programme als einfache Funktionsaufrufe auszuführen.

# %% [markdown]
# ### Klasse für Daten

# %% [markdown]
# Die Daten-Klasse speichert unsere Daten und Zielfunktion und helft uns diese zu Formatieren. Kategorische Variablen werden mit der Vorverarbeitung zu numerischen Variablen verarbeitet. Daten werden normalisiert, um das Gewicht von unterschiedlichen Skalen der Variablen vergleichbar zu machen.

# %%
class Daten:
    def __init__(self, data_x, data_y, LSTM = False, OneHot = False):
        self.data_x=data_x
        self.data_y=data_y
        self.encoded_y=[]
        if (OneHot):
            self.one_hot()
        if (LSTM):
            self.scaling()
            self.reshape_for_Lstm()
        
    def Vorverarbeitung_Y(self):
        le = preprocessing.LabelEncoder()
        le.fit(self.data_y)
        self.data_y=le.transform(self.data_y)
        self.data_y=pd.DataFrame(self.data_y,columns=['target'])          
        le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
        print(le_name_mapping)

    def splitting(self, von, bis, LSTM = True, OneHot = True):    
        split_x=self.data_x[von:bis].values
        split_y=self.data_y[von:bis].values
        return Daten(split_x, split_y,LSTM, OneHot)

    def make_float(self):      
        self.data_x.astype('float32')

    def reshape_for_Lstm(self):   
        timesteps=1
        samples=int(np.floor(self.data_x.shape[0]/timesteps))   
        self.data_x=self.data_x.reshape((samples,timesteps,self.data_x.shape[1]))   

    def one_hot(self):
        oneHot=OneHotEncoder()
        oneHot.fit(self.data_y.reshape(-1,1))
        self.oneHot=oneHot.transform(self.data_y.reshape(-1,1)).toarray()
       # return self.data_y
    
    def scaling(self,save=False):
        scaler=MinMaxScaler().fit(self.data_x)
        self.data_x=scaler.transform(self.data_x) 
        if save:
            savetxt('test_x_data_OOP.csv',self.data_x,delimiter='.')

# %% [markdown]
# ### Klasse für Zeitreihe

# %% [markdown]
# Die Zeitreihe-Klasse transformiert unsere normale Zeitreihe der Sensor-Daten in eine versetzte Zeitreihe, um die Zielfunktion zu einem anderen Zeitpunkt vorherzusagen.
# Die Zeit-Einheit zwischen Messungen in "pump.csv" ist 1 Minute und somit ist t in Minuten.

# %%
class Zeitreihe:
    def __init__(self,data, n_in=1, n_out=1):
        self.data=data
        self.n_in=n_in
        self.n_out=n_out
    
    def series_to_supervised(self,dropnan=True):
        n_vars = 1 if type(self.data) is list else self.data.shape[1]
        df = pd.DataFrame(self.data)
        cols, namen = list(),list()
        # input sequence (t-n, ... t-1)
        for i in range(self.n_in, 0, -1):
            cols.append(df.shift(i))
            namen +=[('sensor%d(t-%d)' %(j+1, i)) for j in range (n_vars)]
            #forecast sequence (t, t+1, ... t+n)
        for i in range(0, self.n_out):
            cols.append(df.shift(-i))
            if i == 0:
                namen +=[('sensor%d(t)' %(j+1)) for j in range (n_vars)]
            else:
                namen +=[('sensor%d(t+%d)' %(j+1, i)) for j in range (n_vars)]
        # put it all together
        agg = pd.concat(cols, axis=1)
        agg.columns=namen
        # drop rows with NaN values
        if dropnan:
            agg.dropna(inplace=True)
            
        self.data=self.clean_series_to_supervised(agg)
        
        return self.data
    
    def clean_series_to_supervised(self,shifted_data):
        to_remove_list =['sensor'+str(n)+'(t)' for n in range(1,len(self.data.columns)+1)] #now remove all non shifted elements again. so we retreive elements and shifted target
        #to_remove_list_2 =['sensor'+str(n)+'(t-'+ str(i)+')' for n in range(1,len(data_scaled.columns)+1) for i in range(1,Future)] #now remove all non shifted elements again. so we retreive elements and shifted target
        #to_remove_list=to_remove_list_1+to_remove_list_2
        data_y=shifted_data.iloc[:,-1] #Get the target data out before removing unwanted data
        data_x=shifted_data.drop(to_remove_list, axis=1) #remove sensors(t)
        data_x.drop(data_x.columns[len(data_x.columns)-1], axis=1, inplace=True)# remove target(t-n)
        data=pd.concat([data_x,data_y],axis=1)
        data.columns=[*data.columns[:-1],'machine_status'] # rename last column to target name
        return data

# %% [markdown]
# ## Klasse für Künstliche Intelligenz

# %% [markdown]
# Die KI Klasse lädt die Daten, transformiert die Daten, bereitet die Modelle vor und ermöglicht es mit den unterschiedlichen Modellen vorhersagen zu treffen.
#
# Momentan ist das LSTM und der Random Forest fest in der Klasse verbaut. Es wäre sinnvoll dies zu generalisieren und es zuzulassen unterschiedliche Modelle in die KI zu laden und zu vergleichen.
#
# Wir schauen uns sowohl die Klassifizierung an, als auch das Signal (oder Regression). Das Signal ist interessant, um zu verstehen, wie stark das Lernen auf ein Signal anschlägt und ob die Klassifizierung nur knapp oder stark anschlägt.

# %%
class KI:
    def __init__(self, rohdaten, kodiertes_y, vorhersage_zeitpunkt):
        """
        Die Künstliche Intelligenz wird mit mehreren Parametern intialisiert, um Vorausschauende Instandhaltung zu implementieren.
        rohdaten: Sensordaten, die in Zeitreihen verwandelt werden sollen.
        kodiertes_y: Zielfunktion, die mit den Zeitreihen vorhergesagt werden sollen.
        vorhersage_zeitpunkt: Wie viele Zeitpunkte in die Zukunft, dass Modell die Zielfunktion vorhersagen soll.
        """
        self.Rohdaten = pd.concat([rohdaten,kodiertes_y],axis=1)
        self.Vorhersage_Zeitpunkt = vorhersage_zeitpunkt
        self.Zeitreihe = Zeitreihe(self.Rohdaten,self.Vorhersage_Zeitpunkt).series_to_supervised()
        self.Zeitreihen_Sensornamen=self.Zeitreihe.keys()[:-1]

        self.Daten=Daten(self.Zeitreihe[self.Zeitreihen_Sensornamen], self.Zeitreihe['machine_status']) #Create class instance of Data
        self.Daten.Vorverarbeitung_Y() # change Y to mapped target values
        self.Daten.make_float()
        
        self.Train_data = self.Daten.splitting(0,120000)
        self.Val_data = self.Daten.splitting(140000,len(self.Daten.data_x))
        self.Test_data = self.Daten.splitting(120000,140000)

        self.Modell=self.LSTM_Modell_bauen()
        self.Modell.compile(loss={'signal_out':'mean_squared_error',
                            'class_out' :'categorical_crossentropy'},
                             optimizer='adam',
                             metrics={'class_out':'acc'})



    def LSTM_Modell_bauen(self):
        in_shape = (self.Train_data.data_x.shape)
        inputs= tf.keras.Input(shape=(in_shape[1],in_shape[2]))
        x=LSTM(42,activation='relu', input_shape=(in_shape[1],in_shape[2]),return_sequences=True)(inputs)
        x=LSTM(42,activation='relu')(x)
        out_signal=Dense(1, name='signal_out')(x)
        out_class=Dense(3,activation='softmax', name='class_out')(x)
        return tf.keras.Model(inputs=inputs, outputs=[out_signal,out_class])
    
    def plot_training(self,what='loss',saving=False,name='training'):
        fig=plt.figure()
        plt.plot(self.history.history['class_out_'+what])
        plt.plot(self.history.history['val_class_out_'+what])
        plt.xlabel('epoch')
        plt.legend(['train', 'test'])
        if what=='loss':
            plt.title('model loss')
            plt.ylabel('loss')
        elif what=='acc':   
            plt.title('model Acc')
            plt.ylabel('Accuracy')   
        if saving==True:
            fig.savefig( name +'_'+ what + '.png', format='png', dpi=300, transparent=True)
    
    
        plt.xlabel('epoch')
        plt.legend(['train', 'test'])
        if saving==True:
            fig.savefig( name +'_ACC.png', format='png', dpi=300, transparent=True)  
        plt.show()
        
    def plot_signal_hat(self, saving=False, type= 'LSTM', name='results_signal', axis = None):
        if type == 'LSTM':
            yhat = self.YHat
        elif type == 'RF':
            yhat = self.RFR_modell.predict(self.Test_data.data_x.reshape(-1, self.Test_data.data_x.shape[2]))
        
        if axis is None:
            fig= plt.figure()
            plt.plot(self.Test_data.data_y)
            plt.plot(yhat)
            plt.legend(['target','target_predicted'])
            plt.ylabel('Zustand')
            plt.title('Vorhersage des Signals auf Testdaten für ' + name)
        else:
            axis.plot(self.Test_data.data_y)
            axis.plot(yhat)
            axis.legend(['target','target_predicted'],title = "Signal " + name)
        
        if axis is None:
            if saving==True:
                fig.savefig( name +'.png', format='png', dpi=300, transparent=True)
            plt.show()

    def plot_class_hat(self, saving=False, type= 'LSTM', name='results_class', axis = None):   
        if type == 'LSTM':
            yhat = self.YClass
        elif type == 'RF':
            yhat = self.RFC_modell.predict(self.Test_data.data_x.reshape(-1, self.Test_data.data_x.shape[2]))
        
        if axis is None:
            fig= plt.figure()
            plt.plot(self.Test_data.data_y)
            plt.plot(yhat)
            plt.legend(['target','target_predicted'])
            plt.ylabel('Zustand')
            plt.title('Vorhersage der Klasse auf Testdaten für ' + name)
        else:
            axis.plot(self.Test_data.data_y)
            axis.plot(yhat)
            axis.legend(['target','target_predicted'],title = "Klasse " + name)
        
        if axis is None:
            if saving==True:
                fig.savefig( name +'.png', format='png', dpi=300, transparent=True)
            plt.show()

    def LSTM_modell_trainieren(self, modell_name,epoch = 20, batchsize = 32, modell_laden = False, plot_zeigen = True):   
        if modell_laden:
            self.Modell=tf.keras.models.load_model('./model/'+modell_name)
        else:  
            self.history = self.Modell.fit(self.Train_data.data_x, [self.Train_data.data_y, self.Train_data.oneHot], epochs=epoch, batch_size=batchsize, validation_data=(self.Val_data.data_x, [self.Val_data.data_y,self.Val_data.oneHot]), shuffle=False)
            if plot_zeigen:
                self.plot_training(what='loss',
                              saving=True,
                              name=('training_'+ str(self.Vorhersage_Zeitpunkt)))  
                self.plot_training(what='acc',
                              saving=True,
                              name=('training_'+ str(self.Vorhersage_Zeitpunkt))) 
            self.Modell.save('./model/'+str(modell_name))

    def Random_forest_modell_trainieren(self,num_trees = 100, epoch = 1, modell_laden = False, plot_zeigen = True):   
        self.RFR_modell = RandomForestRegressor(n_estimators = num_trees, n_jobs=-1, warm_start = True, max_features = 0.33, verbose = 2)
        for i in range(epoch):
            self.RFR_modell.fit(self.Train_data.data_x.reshape(-1, self.Test_data.data_x.shape[2]), self.Train_data.data_y.ravel())
            self.y_pred_rfr = self.RFR_modell.predict(self.Val_data.data_x.reshape(-1, self.Val_data.data_x.shape[2]))
            cm = confusion_matrix(self.Val_data.data_y.ravel(), np.round(self.y_pred_rfr))
            accuracy = accuracy_score(self.Val_data.data_y.ravel(), np.round(self.y_pred_rfr))
            precision = precision_score(self.Val_data.data_y.ravel(), np.round(self.y_pred_rfr), average = 'weighted')
            recall = recall_score(self.Val_data.data_y.ravel(), np.round(self.y_pred_rfr), average = 'weighted')
            print("Confusion Matrix:", cm)
            print("Accuracy:", accuracy)
            print("Precision:", precision)
            print("Recall:", recall)

        
        self.RFC_modell = RandomForestClassifier(n_estimators = num_trees, n_jobs=-1, warm_start = True, max_features='sqrt', verbose = 2)
        
        for i in range(epoch):
            self.RFC_modell.fit(self.Train_data.data_x.reshape(-1, self.Test_data.data_x.shape[2]), self.Train_data.data_y.ravel())
            self.y_pred_rfc = self.RFC_modell.predict(self.Val_data.data_x.reshape(-1, self.Val_data.data_x.shape[2]))
            cm = confusion_matrix(self.Val_data.data_y.ravel(), self.y_pred_rfc)
            accuracy = accuracy_score(self.Val_data.data_y.ravel(), self.y_pred_rfc)
            precision = precision_score(self.Val_data.data_y.ravel(), self.y_pred_rfc, average = 'weighted')
            recall = recall_score(self.Val_data.data_y.ravel(), self.y_pred_rfc, average = 'weighted')
            print("Confusion Matrix:", cm)
            print("Accuracy:", accuracy)
            print("Precision:", precision)
            print("Recall:", recall)

    def modellzusammenfassung(self):
        self.Modell.summary()

    def vorhersagen(self):
        [yhat,yclass] = self.Modell.predict(self.Test_data.data_x)  
        self.YHat = yhat
        self.YClass=[np.argmax(yclass[i],0) for i in range(len(yclass))] # get final class
        
        cm = confusion_matrix(self.Test_data.data_y.ravel(), np.round(self.YHat))
        accuracy = accuracy_score(self.Test_data.data_y.ravel(), np.round(self.YHat))
        precision = precision_score(self.Test_data.data_y.ravel(), np.round(self.YHat), average = 'weighted')
        recall = recall_score(self.Test_data.data_y.ravel(), np.round(self.YHat), average = 'weighted')
        print("Confusion Matrix:", cm)
        print("Accuracy:", accuracy)
        print("Precision:", precision)
        print("Recall:", recall)

        
        cm = confusion_matrix(self.Test_data.data_y.ravel(), np.array(self.YClass))
        accuracy = accuracy_score(self.Test_data.data_y.ravel(), np.array(self.YClass))
        precision = precision_score(self.Test_data.data_y.ravel(), np.array(self.YClass), average = 'weighted')
        recall = recall_score(self.Test_data.data_y.ravel(), np.array(self.YClass), average = 'weighted')
        print("Confusion Matrix:", cm)
        print("Accuracy:", accuracy)
        print("Precision:", precision)
        print("Recall:", recall)

# %% [markdown]
# ## Vorhersage

# %% [markdown]
# Im Einklang mit der P-F-Kurve modellieren vorrauschauende Instandhaltung für 3 Zeiträume: 10 Minuten, 20 Minuten und 30 Minuten.

# %% [markdown]
# ### Vergleich LSTM und Random Forest für 10 min

# %%
Vorausschauende_Instandhaltungs_KI = KI(rohdaten = visualisierungs_daten, kodiertes_y = kodiertes_Y, vorhersage_zeitpunkt = 10)

print(Vorausschauende_Instandhaltungs_KI.modellzusammenfassung())

Vorausschauende_Instandhaltungs_KI.LSTM_modell_trainieren(modell_name = "Pump_LSTM_F10",epoch=40)

Vorausschauende_Instandhaltungs_KI.vorhersagen()

Vorausschauende_Instandhaltungs_KI.Random_forest_modell_trainieren()
# Out:
# {0.0: 0, 1.0: 1, 2.0: 2}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1, 459)]             0         []
#
#  lstm (LSTM)                 (None, 1, 42)                84336     ['input_1[0][0]']
#
#  lstm_1 (LSTM)               (None, 42)                   14280     ['lstm[0][0]']
#
#  signal_out (Dense)          (None, 1)                    43        ['lstm_1[0][0]']
#
#  class_out (Dense)           (None, 3)                    129       ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 98788 (385.89 KB)
# Trainable params: 98788 (385.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1592 - signal_out_loss: 0.0247 - class_out_loss: 0.1345 - class_out_acc: 0.9579 - val_loss: 0.0229 - val_signal_out_loss: 0.0100 - val_class_out_loss: 0.0129 - val_class_out_acc: 0.9985
# Epoch 2/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.
40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0938 - signal_out_loss: 0.0176 - class_out_loss: 0.0762 - class_out_acc: 0.9720 - val_loss: 0.0134 - val_signal_out_loss: 0.0030 - val_class_out_loss: 0.0104 - val_class_out_acc: 0.9985
# Epoch 34/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1167 - signal_out_loss: 0.0204 - class_out_loss: 0.0963 - class_out_acc: 0.9605 - val_loss: 0.0128 - val_signal_out_loss: 0.0019 - val_class_out_loss: 0.0110 - val_class_out_acc: 0.9985
# Epoch 35/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0693 - signal_out_loss: 0.0158 - class_out_loss: 0.0535 - class_out_acc: 0.9750 - val_loss: 0.0142 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0126 - val_class_out_acc: 0.9985
# Epoch 36/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0511 - signal_out_loss: 0.0123 - class_out_loss: 0.0389 - class_out_acc: 0.9851 - val_loss: 0.0144 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0129 - val_class_out_acc: 0.9985
# Epoch 37/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0519 - signal_out_loss: 0.0124 - class_out_loss: 0.0395 - class_out_acc: 0.9841 - val_loss: 0.0216 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0201 - val_class_out_acc: 0.9985
# Epoch 38/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0703 - signal_out_loss: 0.0159 - class_out_loss: 0.0544 - class_out_acc: 0.9771 - val_loss: 0.0121 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.0103 - val_class_out_acc: 0.9985
# Epoch 39/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0580 - signal_out_loss: 0.0143 - class_out_loss: 0.0438 - class_out_acc: 0.9804 - val_loss: 0.0129 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0114 - val_class_out_acc: 0.9985
# Epoch 40/40
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.0551 - signal_out_loss: 0.0123 - class_out_loss: 0.0428 - class_out_acc: 0.9855 - val_loss: 0.0124 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.0107 - val_class_out_acc: 0.9985
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F10/assets
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F10/assets
# 625/625 [==============================] - 0s 511us/step
# Confusion Matrix: [[    0     1     0]
#  [    0 11609     0]
#  [    0  8390     0]]
# Accuracy: 0.58045
# Precision: 0.3369222025
# Recall: 0.58045
# Confusion Matrix: [[    0     1     0]
#  [    0 11603     6]
#  [    0  1895  6495]]
# Accuracy: 0.9049
# Precision: 0.9180358119795096
# Recall: 0.9049
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
#
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   22.3s
# building tree 32 of 100building tree 33 of 100
#
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.4min finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# Confusion Matrix: [[    0     2     0]
#  [    0 79374     4]
#  [    0     2   114]]
# Accuracy: 0.9998993660058367
# Precision: 0.9998750603377549
# Recall: 0.9998993660058367
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.9s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# Confusion Matrix: [[    0     2     0]
#  [    0 79369     9]
#  [    0     8   108]]
# Accuracy: 0.9997609942638623
# Precision: 0.9997368049845883
# Recall: 0.9997609942638623
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   11.7s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.1s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
Vorausschauende_Instandhaltungs_KI.plot_signal_hat(saving=False, type='LSTM', name='LSTM', axis = axes[0,0])
Vorausschauende_Instandhaltungs_KI.plot_class_hat(saving=False,  type='LSTM', name='LSTM', axis = axes[0,1])
Vorausschauende_Instandhaltungs_KI.plot_signal_hat(saving=False, type='RF', name='RF', axis = axes[1,0])
Vorausschauende_Instandhaltungs_KI.plot_class_hat(saving=False,  type='RF', name='RF', axis = axes[1,1])
fig.savefig('vorhersage_f10.png', format='png', dpi=300, transparent=True)
plt.show()
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# ### Vergleich LSTM und Random Forest für 20 min

# %%
Vorausschauende_Instandhaltungs_KI2 = KI(rohdaten = visualisierungs_daten, kodiertes_y = kodiertes_Y, vorhersage_zeitpunkt = 20)

Vorausschauende_Instandhaltungs_KI2.LSTM_modell_trainieren(modell_name = "Pump_LSTM_F20",epoch=50)

Vorausschauende_Instandhaltungs_KI2.vorhersagen()

Vorausschauende_Instandhaltungs_KI2.Random_forest_modell_trainieren()
# Out:
# {0.0: 0, 1.0: 1, 2.0: 2}
# Epoch 1/50
# 3750/3750 [==============================] - 359s 96ms/step - loss: 0.2053 - signal_out_loss: 0.0487 - class_out_loss: 0.1566 - class_out_acc: 0.9462 - val_loss: 0.0157 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0141 - val_class_out_acc: 0.9985
# Epoch 2/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2310 - signal_out_loss: 0.0376 - class_out_loss: 0.1934 - class_out_acc: 0.9502 - val_loss: 0.0171 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0156 - val_class_out_acc: 0.9985
# Epoch 3/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2253 - signal_out_loss: 0.0368 - class_out_loss: 0.1885 - class_out_acc: 0.9502 - val_loss: 0.0174 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0159 - val_class_out_acc: 0.9985
# Epoch 4/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2226 - signal_out_loss: 0.0362 - class_out_loss: 0.1864 - class_out_acc: 0.9502 - val_loss: 0.0179 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0164 - val_class_out_acc: 0.9985
# Epoch 5/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2215 - signal_out_loss: 0.0360 - class_out_loss: 0.1856 - class_out_acc: 0.9502 - val_loss: 0.0186 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0171 - val_class_out_acc: 0.9985
# Epoch 6/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2213 - signal_out_loss: 0.0357 - class_out_loss: 0.1857 - class_out_acc: 0.9502 - val_loss: 0.0194 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0179 - val_class_out_acc: 0.9985
# Epoch 7/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2214 - signal_out_loss: 0.0355 - class_out_loss: 0.1859 - class_out_acc: 0.9502 - val_loss: 0.0201 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0186 - val_class_out_acc: 0.9985
# Epoch 8/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2209 - signal_out_loss: 0.0352 - class_out_loss: 0.1858 - class_out_acc: 0.9502 - val_loss: 0.0208 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0192 - val_class_out_acc: 0.9985
# Epoch 9/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2208 - signal_out_loss: 0.0359 - class_out_loss: 0.1849 - class_out_acc: 0.9502 - val_loss: 0.0214 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0198 - val_class_out_acc: 0.9985
# Epoch 10/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2195 - signal_out_loss: 0.0369 - class_out_loss: 0.1826 - class_out_acc: 0.9502 - val_loss: 0.0213 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0197 - val_class_out_acc: 0.9985
# Epoch 11/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2195 - signal_out_loss: 0.0384 - class_out_loss: 0.1811 - class_out_acc: 0.9502 - val_loss: 0.0209 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.0192 - val_class_out_acc: 0.9985
# Epoch 12/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.2191 - signal_out_loss: 0.0384 - class_out_loss: 0.1807 - class_out_acc: 0.9502 - val_loss: 0.0204 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.
50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0214 - signal_out_loss: 0.0037 - class_out_loss: 0.0177 - class_out_acc: 0.9956 - val_loss: 0.0291 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0275 - val_class_out_acc: 0.9985
# Epoch 43/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0217 - signal_out_loss: 0.0040 - class_out_loss: 0.0177 - class_out_acc: 0.9957 - val_loss: 0.0274 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.0257 - val_class_out_acc: 0.9985
# Epoch 44/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0202 - signal_out_loss: 0.0040 - class_out_loss: 0.0163 - class_out_acc: 0.9961 - val_loss: 0.0230 - val_signal_out_loss: 0.0018 - val_class_out_loss: 0.0212 - val_class_out_acc: 0.9985
# Epoch 45/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0159 - signal_out_loss: 0.0030 - class_out_loss: 0.0129 - class_out_acc: 0.9970 - val_loss: 0.0191 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0175 - val_class_out_acc: 0.9985
# Epoch 46/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0163 - signal_out_loss: 0.0031 - class_out_loss: 0.0132 - class_out_acc: 0.9969 - val_loss: 0.0197 - val_signal_out_loss: 0.0016 - val_class_out_loss: 0.0182 - val_class_out_acc: 0.9985
# Epoch 47/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0161 - signal_out_loss: 0.0030 - class_out_loss: 0.0131 - class_out_acc: 0.9970 - val_loss: 0.0195 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0180 - val_class_out_acc: 0.9985
# Epoch 48/50
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.0159 - signal_out_loss: 0.0030 - class_out_loss: 0.0130 - class_out_acc: 0.9970 - val_loss: 0.0208 - val_signal_out_loss: 0.0017 - val_class_out_loss: 0.0192 - val_class_out_acc: 0.9985
# Epoch 49/50
# 3750/3750 [==============================] - 966s 258ms/step - loss: 0.0150 - signal_out_loss: 0.0028 - class_out_loss: 0.0121 - class_out_acc: 0.9973 - val_loss: 0.0199 - val_signal_out_loss: 0.0019 - val_class_out_loss: 0.0180 - val_class_out_acc: 0.9985
# Epoch 50/50
# 3750/3750 [==============================] - 933s 249ms/step - loss: 0.0156 - signal_out_loss: 0.0029 - class_out_loss: 0.0127 - class_out_acc: 0.9972 - val_loss: 0.0228 - val_signal_out_loss: 0.0018 - val_class_out_loss: 0.0211 - val_class_out_acc: 0.9985
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F20/assets
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F20/assets
# 625/625 [==============================] - 1s 621us/step
# Confusion Matrix: [[    0     1     0]
#  [    0 11609     0]
#  [    0  8028   362]]
# Accuracy: 0.59855
# Precision: 0.7626329081372849
# Recall: 0.59855
# Confusion Matrix: [[    0     1     0]
#  [    0 11595    14]
#  [    0  8018   372]]
# Accuracy: 0.59835
# Precision: 0.7474234338668954
# Recall: 0.59835
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 31.8min
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 61.1min finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# Confusion Matrix: [[    0     2     0]
#  [    0 79356    12]
#  [    0     2   114]]
# Accuracy: 0.9997987066904864
# Precision: 0.9997855216984951
# Recall: 0.9997987066904864
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.0s
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# Confusion Matrix: [[    0     2     0]
#  [    0 79353    15]
#  [    0     9   107]]
# Accuracy: 0.9996728983720403
# Precision: 0.9996570106749679
# Recall: 0.9996728983720403
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   17.0s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.1s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
Vorausschauende_Instandhaltungs_KI2.plot_signal_hat(saving=False, type='LSTM', name='LSTM', axis = axes[0,0])
Vorausschauende_Instandhaltungs_KI2.plot_class_hat(saving=False,  type='LSTM', name='LSTM', axis = axes[0,1])
Vorausschauende_Instandhaltungs_KI2.plot_signal_hat(saving=False, type='RF', name='RF', axis = axes[1,0])
Vorausschauende_Instandhaltungs_KI2.plot_class_hat(saving=False,  type='RF', name='RF', axis = axes[1,1])
fig.savefig('vorhersage_f20.png', format='png', dpi=300, transparent=True)
plt.show()
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# ### Vergleich LSTM und Random Forest für 30 min

# %%
Vorausschauende_Instandhaltungs_KI3 = KI(rohdaten = visualisierungs_daten, kodiertes_y = kodiertes_Y, vorhersage_zeitpunkt = 30)

Vorausschauende_Instandhaltungs_KI3.LSTM_modell_trainieren(modell_name = "Pump_LSTM_F30",epoch=120)

Vorausschauende_Instandhaltungs_KI3.vorhersagen()

Vorausschauende_Instandhaltungs_KI3.Random_forest_modell_trainieren()
# Out:
# {0.0: 0, 1.0: 1, 2.0: 2}
# Epoch 1/120
# 3750/3750 [==============================] - 151s 40ms/step - loss: 0.2129 - signal_out_loss: 0.0322 - class_out_loss: 0.1807 - class_out_acc: 0.9491 - val_loss: 0.0162 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0147 - val_class_out_acc: 0.9985
# Epoch 2/120
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.2313 - signal_out_loss: 0.0349 - class_out_loss: 0.1964 - class_out_acc: 0.9502 - val_loss: 0.0181 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0166 - val_class_out_acc: 0.9985
# Epoch 3/120
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.2232 - signal_out_loss: 0.0347 - class_out_loss: 0.1885 - class_out_acc: 0.9466 - val_loss: 0.0180 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0165 - val_class_out_acc: 0.9985
# Epoch 4/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2220 - signal_out_loss: 0.0345 - class_out_loss: 0.1875 - class_out_acc: 0.9469 - val_loss: 0.0182 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0167 - val_class_out_acc: 0.9985
# Epoch 5/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2206 - signal_out_loss: 0.0340 - class_out_loss: 0.1866 - class_out_acc: 0.9471 - val_loss: 0.0183 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0168 - val_class_out_acc: 0.9985
# Epoch 6/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2192 - signal_out_loss: 0.0341 - class_out_loss: 0.1851 - class_out_acc: 0.9479 - val_loss: 0.0181 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0166 - val_class_out_acc: 0.9985
# Epoch 7/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2179 - signal_out_loss: 0.0343 - class_out_loss: 0.1837 - class_out_acc: 0.9485 - val_loss: 0.0179 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0164 - val_class_out_acc: 0.9985
# Epoch 8/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2168 - signal_out_loss: 0.0343 - class_out_loss: 0.1826 - class_out_acc: 0.9490 - val_loss: 0.0176 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0162 - val_class_out_acc: 0.9985
# Epoch 9/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2160 - signal_out_loss: 0.0342 - class_out_loss: 0.1818 - class_out_acc: 0.9493 - val_loss: 0.0175 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0160 - val_class_out_acc: 0.9985
# Epoch 10/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2158 - signal_out_loss: 0.0337 - class_out_loss: 0.1821 - class_out_acc: 0.9495 - val_loss: 0.0171 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0156 - val_class_out_acc: 0.9985
# Epoch 11/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.
- val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0161 - val_class_out_acc: 0.9985
# Epoch 114/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2170 - signal_out_loss: 0.0365 - class_out_loss: 0.1805 - class_out_acc: 0.9482 - val_loss: 0.0175 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0160 - val_class_out_acc: 0.9985
# Epoch 115/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2167 - signal_out_loss: 0.0366 - class_out_loss: 0.1801 - class_out_acc: 0.9485 - val_loss: 0.0174 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0159 - val_class_out_acc: 0.9985
# Epoch 116/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2164 - signal_out_loss: 0.0366 - class_out_loss: 0.1798 - class_out_acc: 0.9485 - val_loss: 0.0173 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0158 - val_class_out_acc: 0.9985
# Epoch 117/120
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.2161 - signal_out_loss: 0.0367 - class_out_loss: 0.1795 - class_out_acc: 0.9485 - val_loss: 0.0172 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0157 - val_class_out_acc: 0.9985
# Epoch 118/120
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.2159 - signal_out_loss: 0.0367 - class_out_loss: 0.1792 - class_out_acc: 0.9487 - val_loss: 0.0171 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0156 - val_class_out_acc: 0.9985
# Epoch 119/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2156 - signal_out_loss: 0.0367 - class_out_loss: 0.1789 - class_out_acc: 0.9490 - val_loss: 0.0170 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0155 - val_class_out_acc: 0.9985
# Epoch 120/120
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.2154 - signal_out_loss: 0.0367 - class_out_loss: 0.1787 - class_out_acc: 0.9490 - val_loss: 0.0170 - val_signal_out_loss: 0.0015 - val_class_out_loss: 0.0155 - val_class_out_acc: 0.9985
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F30/assets
# INFO:tensorflow:Assets written to: ./model/Pump_LSTM_F30/assets
# 625/625 [==============================] - 1s 676us/step
# Confusion Matrix: [[    0     1     0]
#  [    0 11609     0]
#  [    0  8390     0]]
# Accuracy: 0.58045
# Precision: 0.3369222025
# Recall: 0.58045
# Confusion Matrix: [[    0     1     0]
#  [    0 11609     0]
#  [    0  8390     0]]
# Accuracy: 0.58045
# Precision: 0.3369222025
# Recall: 0.58045
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  1.0min
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  6.1min finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion Matrix: [[    0     2     0]
#  [    0 79349     9]
#  [    0     2   114]]
# Accuracy: 0.9998364286073783
# Precision: 0.9998177052579846
# Recall: 0.9998364286073783
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    5.3s
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# Confusion Matrix: [[    0     2     0]
#  [    0 79342    16]
#  [    0    10   106]]
# Accuracy: 0.9996476923851225
# Precision: 0.9996324208611588
# Recall: 0.9996476923851225
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   22.3s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.1s finished
# /Users/jgruebel/.pyenv/versions/3.11.2/envs/jupyter_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
Vorausschauende_Instandhaltungs_KI3.plot_signal_hat(saving=False, type='LSTM', name='LSTM', axis = axes[0,0])
Vorausschauende_Instandhaltungs_KI3.plot_class_hat(saving=False,  type='LSTM', name='LSTM', axis = axes[0,1])
Vorausschauende_Instandhaltungs_KI3.plot_signal_hat(saving=False, type='RF', name='RF', axis = axes[1,0])
Vorausschauende_Instandhaltungs_KI3.plot_class_hat(saving=False,  type='RF', name='RF', axis = axes[1,1])
fig.savefig('vorhersage_f30.png', format='png', dpi=300, transparent=True)
plt.show()
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.0s finished
